# %%
import random

player= input('Enter your choice (rock/paper/scissor): ')
computer_int= random.randint(0,2)
if computer_int == 0:
    computer='rock'
elif computer_int ==1:
    computer = 'paper'
elif computer_int == 2:
    computer = 'scissor'
else:
    computer = 'error'

if player == computer:
    print ('Computer choice:', computer)
    print ('A TIE!')
    
elif player == 'rock':
    if computer == 'paper':
        print ('Computer choice:', computer)
        print ('YOU LOSE!')
    else:
        print ('Computer choice:', computer)
        print ('YOU WIN!')
elif player == 'paper':
    if computer == 'scissor':
        print ('Computer choice:', computer)
        print ('YOU LOSE!')
    else:
        print ('Computer choice:', computer)
        print ('YOU WIN!')
elif player == 'scissor':
    if computer == 'rock':
        print ('Computer choice:', computer)
        print ('YOU LOSE!')
    else:
        print ('Computer choice:', computer)
        print ('YOU WIN!')
else:
    print ('Invaild Entry')

# %%
import random

def rockPaperScissors():
    playerScore = 0
    computerScore = 0
     p = input("Type 'r' for rock, 'p' for paper or 's' for scissors: ")
    choices = ['r', 'p', 's']
    c = random.choice(choices)
  
    print ("Your move:", p)
    print ("Computer's move:", c)
   
    if p == c:
        print ("Tie")
    elif p == 'r' and c == 's':
        playerScore += 1
        print ("You win")
    elif p == 'p' and c == 'r':
        playerScore += 1
        print ("You win")
    elif p == 's' and c == 'p':
        playerScore += 1
        print ("You win")
    elif c == 'r' and p == 's':
        computerScore += 1
        print ("You lose")
    elif c == 'p' and p == 'r':
        computerScore += 1
        print ("You lose")
    elif c == 's' and p == 'p':
        computerScore += 1
        print ("You lose")
    else:
        print ("Try again")
    return playerScore, computerScore

player = 0
computer = 0

while True:
    p, c = rockPaperScissors()
    player += p
    computer += c
    print ("Your score:", str(player)+ ", Computer score:", computer)
